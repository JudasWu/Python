# %%
import ffn
prices = ffn.get('aapl,msft', start='2010-01-01')
prices
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                   aapl        msft
# Date
# 2010-01-04    6.487535   23.522566
# 2010-01-05    6.498750   23.530163
# 2010-01-06    6.395378   23.385761
# 2010-01-07    6.383555   23.142555
# 2010-01-08    6.425995   23.302156
# ...                ...         ...
# 2023-08-14  179.460007  323.355408
# 2023-08-15  177.449997  321.179962
# 2023-08-16  176.570007  320.399994
# 2023-08-17  174.000000  316.880005
# 2023-08-18  174.490005  316.480011
#
# [3430 rows x 2 columns]

# %%
ax = prices.rebase().plot(figsize=(10, 5))

# %%
import ffn
prices = ffn.get('2330.TW,2303.TW', start='2010-01-01')
prices
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                 2330tw     2303tw
# Date
# 2010-01-04   41.729420   9.028941
# 2010-01-05   41.472221   9.135164
# 2010-01-06   41.729420   9.772501
# 2010-01-07   41.279327   9.772501
# 2010-01-08   41.150745   9.666279
# ...                ...        ...
# 2023-08-14  541.000000  45.000000
# 2023-08-15  542.000000  45.450001
# 2023-08-16  542.000000  43.750000
# 2023-08-17  544.000000  43.599998
# 2023-08-18  539.000000  43.799999
#
# [3337 rows x 2 columns]

# %%
ax = prices.rebase().plot(figsize=(10, 5))

# %%
import csv
import pandas as pd

with open('codeSearch.csv',encoding='utf-8',newline='') as file:
    next(file) #跳過第一行
    csv_reader = csv.reader(file)
    stock_codes = {}
    for item in csv_reader:
        key = item[2]
        stock_codes[key] = item[3]  
code_series:pd.Series = pd.Series(stock_codes)
code_series
# Out:
# 1101      台泥
# 1102      亞泥
# 1103      嘉泥
# 1104      環泥
# 1108      幸福
#         ...
# 9944      新麗
# 9945     潤泰新
# 9946    三發地產
# 9955      佳龍
# 9958     世紀鋼
# Length: 975, dtype: object
