# %%
#codespace 要安裝中文字型
#命令列:sudo apt-get update -y
#命令列:sudo apt-get install -y fonts-wqy-zenhei
#install 要加-y
#說明網址:https://askubuntu.com/questions/490829/how-can-i-install-chinese-fonts-on-kubuntu-14-04
#codespace字型位置:/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc
#ios字型位置 font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8)
#window字型位置 font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8)
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
font=FontProperties(fname='/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=8)
font1=FontProperties(fname='/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=12)
#window font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8)

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student2 = {'國文':90, '英文':75, '數學':98, '歷史':65, '探索':75}
subjects =list(student1.keys())
value1 =list(student1.values())
value2 = list(student2.values())

fig = plt.figure(figsize=(8,5), dpi=250, facecolor="#cccccc")
ax = fig.add_subplot(1,2,1)
ax.set_title("學生分數比較表",fontproperties=font1)
ax.set_xlabel("科目",fontproperties=font)
ax.set_ylabel("分數",fontproperties=font)
ax.plot(subjects,value1,"c--o")
ax.plot(subjects,value2,"r-*")
ax.set_xticklabels(subjects,fontproperties=font)
ax.legend(["學生1","學生2"],prop=font)

x_locations = ax.get_xticks()
#y_locations = ax.get_yticks()

for i in range(len(x_locations)):
    #annotate(顯示字串,X座標,Y座標)
    ax.annotate(str(value1[i]),(x_locations[i]+0.05,value1[i]))
    ax.annotate(str(value2[i]),(x_locations[i]+0.05,value2[i])) 
      
value1_total = 0
value2_total = 0
for score in value1:
    value1_total += score

for score in value2:
    value2_total += score

ax.annotate(f'學生1總分{value1_total}\n學生2總分{value2_total}',(3.0,93),fontproperties=font)



ax_1 = fig.add_subplot(1,2,2)
ax_1.set_title("英文分數放大比較",fontproperties=font)
ax_1.set_xlabel("科目",fontproperties=font)
ax_1.set_ylabel("分數",fontproperties=font)
ax_1.plot(subjects,value1,'m-.o')
ax_1.plot(subjects,value2,'c--o')
ax_1.set_xticklabels(subjects,fontproperties=font)
ax_1.annotate(f'學生1總分{value1_total}\n學生2總分{value2_total}',(2.5,85),fontproperties=font)
ax_1.legend([f"學生1:{value1_total}",f"學生2:{value2_total}"],prop=font)
ax_1.grid(axis='y')
ax_1.axis(xmin=0.5,xmax=1.5,ymin=70,ymax=85)
plt.show()
# Out:
# /tmp/ipykernel_14252/3321822184.py:28: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(subjects,fontproperties=font)
# /tmp/ipykernel_14252/3321822184.py:57: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax_1.set_xticklabels(subjects,fontproperties=font)
